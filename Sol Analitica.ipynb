# %%
import numpy as np
from matplotlib.axes import Axes
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
N=200
M=200
v0=5
dl=2

# %%
def V_teo(P, a, b, V0,x,y): # P:#de ciclos, N=#x, M=#y, dl=dx=dy
    
    constante = ((-4*V0)/np.pi)
    suma = 0
    for n in range(1,P+1,2):
        m = ((n*np.pi)/(a))
        term = (1/n)*(np.cosh(m*y)-((1+np.cosh(m*b))/np.sinh(m*b))*np.sinh(m*y))*np.sin(m*x)
        suma += term
    return (constante*suma)

# %%
x = np.linspace(0,N*dl,N)
y = np.linspace(0,M*dl,M)

teo = np.array(np.zeros((M,N)))
for i in range (0,len(teo)):
    for j in range (0,len(teo[0])):
        teo[i][j] = V_teo(100, N*dl, M*dl, v0, x[j],y[i])


X,Y = np.meshgrid(x,y)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X,Y,teo, cmap='viridis')

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')

ax.set_title('Solución Teórica')

plt.show()

#plt.figure(figsize=(8, 6))
#plt.imshow(teo, extent=(np.min(x), np.max(x), np.min(y), np.max(y)), origin='lower', cmap='viridis')
#plt.colorbar(label='z')
#plt.xlabel('x')
#plt.ylabel('y')
#plt.title('V(x,y) Analítica')
#plt.grid(True)
#plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.imshow(teo, extent=(np.min(x), np.max(x), np.min(y), np.max(y)), origin='lower', cmap='viridis')
plt.colorbar(label='z')
plt.xlabel('x')
plt.ylabel('y')
plt.title('V(x,y) Teorico')
plt.grid(True)
plt.show()
